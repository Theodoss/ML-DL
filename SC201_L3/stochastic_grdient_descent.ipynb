# %%
#  File: stochastic_gradient_descent.ipynb
#  ----------------------------
#  This file shows student the fundamental concepts of 
#  machine learing:
#      - loss function
#      - linear regression
#      - training process

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# This function computes the L2 loss which is 
# ----------------------------------------
# [(theta*x_i+b - y_i)**2]
# ----------------------------------------
# of data (x_i, y_i) to the line y_i = theta*x_i + b
# 
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x_i=0
# x_i: float, 1 data point
# y_i: float, 1 data point
# return: float, the L2 loss of 1 data point

def loss_function(theta, b, x_i, y_i):
    ############
    ##  TODO  ##
    ############
    return (theta*x_i+b-y_i)**2

# %%
# You should see 0.25
print(loss_function(0.5, 1.5, 2, 2))
# Out:
# 0.25

# %%
# This function returns the partial derivative of L2 loss function
# with respect to theta: 
# --------------------------------------
# 2*(theta*x_i+b - y_i)*x_i
# --------------------------------------
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x_i=0
# x_i: float, 1 data point
# y_i: float, 1 data point
# return: float, the dJ_dtheta of 1 data point

def dL_dtheta(theta, b, x_i, y_i):
    ############
    ##  TODO  ##
    ############
    return 2*(theta*x_i+b - y_i)*x_i

# %%
# You should see 2.0
print(dL_dtheta(0.5, 1.5, 2, 2))
# Out:
# 2.0

# %%
# This function returns the partial derivative of L2 loss function
# with respect to b: 
# --------------------------------------
# 2*(theta*x_i+b - y_i)
# --------------------------------------
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x=0
# x_i: float, 1 data point
# y_i: float, 1 data point
# return: float, the dJ_db of 1 data point

def dL_db(theta, b, x_i, y_i):
    ############
    ##  TODO  ##
    ############
    return 2*(theta*x_i+b - y_i)

# %%
# You should see 1.0
print(dL_db(0.5, 1.5, 2, 2))
# Out:
# 1.0

# %%
# ---------- DO NOT EDIT THE CODE BELOW THIS LINE ---------- #

# %%
x = [6.1101,5.5277,8.5186,7.0032,5.8598,8.3829,7.4764,8.5781,6.4862,5.0546,5.7107,10.164,5.734,8.4084,5.6407,5.3794,6.3654,5.1301,6.4296,7.0708,6.1891]

# %%
y = [6.592,9.1302,13.662,11.854,6.8233,11.886,4.3483,12,6.5987,3.8166,3.2522,15.505,3.1551,7.2258,0.71618,3.5129,5.3048,0.56077,3.6518,5.3893,3.1386]

# %%
# ---------- Showing your data ---------- #

# %%
plt.scatter(x, y)
axes = plt.gca()
axes.set_xlim([0,12])
axes.set_ylim([0,30])
# Out:
# (0.0, 30.0)

# %%
# ---------- Initialize your theta ---------- #

# %%
theta = -1 #####TODO#####
b = -1#####TODO#####

# %%
# ---------- Initialize your alpha ---------- #

# %%
# TODO: which value is appropriate for an ideal alpha?

# %%
alpha = 0.01#####TODO#####

# %%
# ---------- Training process ---------- #
# ---- 11 epochs over all data ----- #

# %%
theta_history = []
b_history = []
loss_history = []
cost_history = []
# In SGD, we name '1 iteration through all data' as '1 epoch'!
for epoch in range(11):
    cost = 0
    for i in range(len(x)):
        x_i,y_i = x[i],y[i]
        theta_history.append(theta)
        b_history.append(b)
        loss = loss_function(theta, b, x_i, y_i)
        cost += loss
        loss_history.append(loss)

        #SGD
        theta = theta - alpha*(dL_dtheta(theta, b, x_i, y_i))
        b = b - alpha * dL_db(theta, b, x_i, y_i)
    cost_history.append(cost/len(x))
    ############
    ##  TODO  ##
    ############

# %%
# ---------- Theta changes during training process ---------- #

# %%
print(loss_history)
# Out:
# [187.74754441, 40.10387817142657, 8.03267053006893, 0.060943501351783266, 8.709001155814232, 0.18507236048900397, 39.745271193189424, 59.47845279559986, 24.303089504895006, 2.894957349361912, 4.46620256842369, 58.195479832745114, 91.52833997291408, 7.2757836177195285, 8.93374265785677, 3.506203009150852, 3.3649258395843735, 10.236317804404887, 0.5871839724229477, 1.932300855813614, 2.0183274842779393, 10.164720982668447, 16.019314442054387, 1.636333264439351, 0.1423790033510549, 8.337239283689373, 0.09998228821461791, 38.793362055949395, 58.578833832044495, 23.321808106344033, 2.614253404591043, 4.4521702947786, 54.39688495060662, 86.07278647394143, 7.312100745877807, 8.305004919603613, 3.7004788085587212, 3.243518135531964, 9.875773186744212, 0.5166067972283958, 1.8210241076140683, 1.9071188068767402, 10.248063406892005, 16.286577444556293, 1.2695607094004526, 0.23917919050376196, 8.03165099541185, 0.04143604161726394, 37.877036528024085, 57.72049387001984, 22.39961311253902, 2.3585858822477768, 4.4387243997428865, 50.87593507828699, 81.00048884610936, 7.34700266865759, 7.723831908153053, 3.891628649395166, 3.1292311770345056, 9.536224117376337, 0.45319241904610613, 1.7174522299992698, 1.8034726746736358, 10.328274657022277, 16.544850663616828, 0.9616055787754703, 0.35540878829668576, 7.7440709510829855, 0.009135689488459282, 37.00893051862709, 56.903638593900645, 21.533062668677783, 2.1258513878566148, 4.425854291483645, 47.61134228954716, 76.2827937296436, 7.3805375629133145, 7.186509133889547, 4.079382970425799, 3.021600229540464, 9.216309286038303, 0.3963003897104672, 1.6210150215406551, 1.7068360929682156, 10.40545846895815, 16.794337983836872, 0.7064944853175918, 0.48836280856620023, 7.473319230716168, 6.282574520617907e-05, 36.18621389773595, 56.12606817023422, 20.718436827649963, 1.9140991394157822, 4.413534582855262, 44.5835256038983, 71.89329416082245, 7.4127557016132055, 6.689616433672916, 4.263515934559229, 2.9201936785868456, 8.914763618196533, 0.3453446674364953, 1.531186259996303, 1.6166984151319403, 10.47971638419078, 17.03524849753377, 0.4987882728151491, 0.6356023759977257, 7.2182999866052855, 0.011480663293597045, 35.40624131710434, 55.385712951269795, 19.952284492673126, 1.7215403188073581, 4.40174106333738, 41.77444190133443, 67.80762732949432, 7.443705789254951, 6.230005371248129, 4.443840768593911, 2.824610433015203, 8.630411083405805, 0.2997890989541044, 1.4474802282810786, 1.532588011845498, 10.55114767032173, 17.267795182301857, 0.3335366310034446, 0.7949312126017003, 6.977995106434281, 0.040909671365322385, 34.66653907747535, 54.68062491370994, 19.231402974077533, 1.5465347817375465, 4.3904506401402505, 39.16746328473897, 64.0033128411481, 7.473434985207361, 5.804777435170667, 4.620205736346082, 2.7344776351509665, 8.362158035299982, 0.25914327603743964, 1.3694485195641026, 1.4540692061552143, 10.619849258684749, 17.492193723079595, 0.20623647625355795, 0.9643741092547243, 6.751458370353687, 0.08610525162850168, 33.96479298409691, 54.00896970907825, 18.552819147625723, 1.387578851852911, 4.379641282573837, 36.74726430145626, 60.45960392787864, 7.501988929458541, 5.411263995060941, 4.792490473892617, 2.6494485489932313, 8.108987068437484, 0.22295873208908154, 1.2966770977308337, 1.38073945297022, 10.685915697242882, 17.708661465462438, 0.11279378912872852, 1.1421572198531178, 6.537810062791845, 0.14503728513028327, 33.29883711356998, 53.369019279527926, 17.913772086823442, 1.2432941108474378, 4.369291969478816, 34.49971822808183, 57.157350565103556, 7.529411770397834, 5.047007874000949, 4.960602656091737, 2.569200612297643, 7.869951351050464, 0.19082545103572437, 1.2287835926556308, 1.3122267433479495, 10.749439117099211, 17.917416488138905, 0.049488625095156676, 1.3266900270994113, 6.336232002915376, 0.2158713958556424, 32.666643421170285, 52.75914499651749, 17.31169705192653, 1.1124171035375188, 4.359382639530901, 32.41180168692276, 54.078873535190944, 7.555746194295926, 4.709746406400237, 5.124474 ...

# %%
theta = theta_history[0]
b = b_history[0]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("1 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: -1, b = -1

# %%
theta = theta_history[1]
b = b_history[1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("2 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.6744240242000001, b = -0.9305759646052885

# %%
theta = theta_history[2]
b = b_history[2]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("3 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.3745362259703078, b = -0.8813209232391042

# %%
theta = theta_history[3]
b = b_history[3]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("4 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.857403973993215, b = -0.9069041346314941

# %%
theta = theta_history[4]
b = b_history[4]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("5 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.8228267418358581, b = -0.9069984567073619

# %%
theta = theta_history[5]
b = b_history[5]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("6 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.476969428748597, b = -0.9254873967448353

# %%
# ---------- Plot the errors over the training process ---------- #

# %%
plot_x = list(range(len(loss_history)))
plot_y = loss_history
plt.plot(plot_x, plot_y)
plt.title("Errors over epochs", color = 'blue')
# Out:
# Text(0.5, 1.0, 'Errors over epochs')

# %%
if b > 0:
    print(f'############ Final equation: y = {theta_history[-1]}x+{b} ############')
else:
    print(f'############ Final equation: y = {theta_history[-1]}x{b} ############')
# Out:
# ############ Final equation: y = 1.3162400236002907x-0.9254873967448353 ############

# %%
theta = theta_history[-1]
b = b_history[-1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("Final Model", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.3162400236002907, b = -3.917648034990881
